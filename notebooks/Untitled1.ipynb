# %%
from icemodels.absorbance_in_filters import u, np, atmo_model
xarr = np.linspace(1.0*u.um, 30.0*u.um, 50000)
phx4000 = atmo_model(4000, xarr=xarr)

# %%
import pylab as pl
pl.plot(xarr, phx4000['fnu'])
pl.xlim(1.7,5.3);
