# %%
from astropy.io import fits

# %%
fh = fits.open('/orange/adamginsburg/jwst/brick/gtc-bubble/data/2025/OB0003/f.51Oph_29May_nospikes.fits')
fh, fh.info()
# Out:
# Filename: /orange/adamginsburg/jwst/brick/gtc-bubble/data/2025/OB0003/f.51Oph_29May_nospikes.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     251   (1742,)   float32
# ([<astropy.io.fits.hdu.image.PrimaryHDU object at 0x14e7e0c6f620>], None)

# %%
import pylab as pl

# %%
fh[0].header['WAT2_002']
# Out:
# ' INDEF 1. 0. 5 1742 1.99 1.99026 1.99053 1.99079 1.99106 1.99132 1.9'

# %%
pl.plot(fh[0].data)
